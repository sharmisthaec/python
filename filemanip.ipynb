# %%
with open("//home//parwez//Desktop//Ticket_Analysis//wfa4mdm.txt") as file1:
    keyword = 'backup'
    file1
    for line in file1:
        if keyword in line:
            print(line)
            with open("/home/parwez/Desktop/newf.txt", 'a+') as file2:
                file2.write(line)
# Out:
# AEZAS#GEZ0FSBK01 SCRIPTNAME "/usr/local/bin/bck/backup_incr_aezas_gior"
#
# AEZAS#MEZ0FSBK01 SCRIPTNAME "/usr/local/bin/bck/backup_full_aezas_mese"
#
# AEZAS#SEZ0FSBK01 SCRIPTNAME "/usr/local/bin/bck/backup_full_aezas_sett"
#
# AEZDB#GEZ0DR0105 SCRIPTNAME "/db/aez000/admin/bckScripts/begin_backup_FC.sh"
#
# AEZDB#GEZ0TX0904 SCRIPTNAME "/appl/aez000/ez0/script/backupfile.ksh $SND CA_TOT.txt"
#
# AEZ_DB#GEZ0BKFS01 SCRIPTNAME "/usr/local/bin/bck/backup_incr_aez_gior"
#
# AEZ_DB#GEZ0EXBK02 SCRIPTNAME "/usr/local/bin/bck/backup_dump_aez0001p_gior.sh"
#
#          DESCRIPTION "EAI Trasporti backup su nastro"
#
# AEZ_DB#GEZ0EXP0102 SCRIPTNAME "/usr/local/bin/bck/backup_dump_aez0001p_gior.sh"
#
# AEZ_DB#GEZ0FSBK01 SCRIPTNAME "/usr/local/bin/bck/backup_incr_fs_gior"
#
# AEZ_DB#GEZ0TX0904 SCRIPTNAME "/appl/aez000/ez0/script/backupfile.ksh $SND CA_TOT.txt"
#
# AEZ_DB#GEZ0VGBK01 DOCOMMAND "/usr/local/bin/bck/backup_incr_fs_rootvg_gior"
#
# ...
